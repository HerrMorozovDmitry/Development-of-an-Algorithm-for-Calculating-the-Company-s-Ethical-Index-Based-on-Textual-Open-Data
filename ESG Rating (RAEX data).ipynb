# %%
import os
import warnings
import requests
import urllib3
from urllib.request import urlopen
from urllib.parse import urlparse
from bs4 import BeautifulSoup
from pypdf import PdfReader
import pandas as pd
import numpy as np
import re
import nltk
from nltk.tokenize import sent_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from pymorphy2 import MorphAnalyzer

warnings.filterwarnings("ignore")
urllib3.disable_warnings()

# %% [markdown]
# ### Ссылки на ESG рейтинг RAEX

# %% [markdown]
# * https://www.raexpert.eu/esg_corporate_ranking/#conf-tab-1
# * https://raex-rr.com/ESG/ESG_companies/ESG_rating_companies/2023.4/

# %% [markdown]
# ## Сбор данных RAEX

# %% [markdown]
# ### Парсинг сайтов компаний из рейтинга

# %%
stopwords_ru = stopwords.words("russian")
morph = MorphAnalyzer()

headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.106 Safari/537.36',
    "accept": "application/json"
}

timeout = (5, 25)

raex_list = pd.read_excel("RAEX list.xlsx").dropna(subset=["url_sustainability"]).reset_index(drop=True)
raex_list
# Out:
#            №                                      Название Код MOEX  \
# 0          1                                          НЛМК     NLMK
# 1          2                                       «Полюс»     PLZL
# 2          3                                   «Уралкалий»        -
# 3          4                                  «ЭЛ5-Энерго»     ELFV
# 4          5                                  «Полиметалл»     POLY
# ..       ...                                           ...      ...
# 136      153                                      Кордиант        -
# 137      155  «Промышленно-металлургический холдинг» (ПМХ)        -
# 138      156    "Титан", группа компаний (деревообработка)        -
# 139      157                                «Минудобрения»        -
# 140  158-160              «Петропавловск», группа компаний        -
#
#               Подотрасль ESG-рейтинг   E Rank E-рейтинг   S Rank S-рейтинг  \
# 0     Чёрная металлургия          AA        2        AA        2        AA
# 1    Драгоценные металлы          AA        1       AAA       14         A
# 2           Агрохимикаты           A        6       BBB        1        AA
# 3      Электроэнергетика           A        9       BBB        9         A
# 4    Драгоценные металлы           A        4         A        5         A
# ..                   ...         ...      ...       ...      ...       ...
# 136     Производство шин           C      154         C      154         C
# 137   Чёрная металлургия           C      156         C      148        CC
# 138      Деревообработка           C      148         C      152         C
# 139         Агрохимикаты           C      157         C      157         C
# 140  Драгоценные металлы           M  158-160         C  158-160         C
#
#       G Rank G-рейтинг  Год последней оцененной отчетности  \
# 0         21         A                                2021
# 1         27         A                                2021
# 2          6        AA                                2021
# 3          2       AAA                                2021
# 4         12        AA                                2021
# ..       ...       ...                                 ...
# 136      142        CC                                2020
# 137      149        CC                                2020
# 138  152-154        CC                                2020
# 139  157-160         C                                2021
# 140  157-160         C                                2021
#
#                                             url  \
# 0                          https://nlmk.com/ru/
# 1                        https://polyus.com/ru/
# 2                  https://www.uralkali.com/ru/
# 3                     https://www.el5-energo.ru
# 4    https://www.polymetalinternational.com/ru/
# ..                                          ...
# 136                         https://cordiant.ru
# 137                   https://www.metholding.ru
# 138                      https://titan-group.ru
# 139                           https://minudo.ru
# 140            https://petropavlovskplc.com/ru/
#
#                                     url_sustainability
# 0                  https://nlmk.com/ru/sustainability/
# 1                https://sustainability.polyus.com/ru/
# 2          https://www.uralkali.com/ru/sustainability/
# 3            https://www.el5-energo.ru/sustainability/
# 4    https://www.polymetalinternational.com/ru/sust...
# ..                                                 ...
# 136               https://www.cordiant-tyre.ru/values/
# 137             https://www.metholding.ru/development/
# 138          https://titan-group.ru/about/development/
# 139              https://minudo.ru/?cid=28&parent_id=5
# 140                          POG-SR2020_RUS_080921.pdf
#
# [141 rows x 14 columns]

# %%
def parsing_pdf(company, pdf):
    reader = PdfReader(f"pdf/{pdf}")
    text = ""
    for page in reader.pages:
        text += page.extract_text() + "\n"

    text = text.replace('-\n', '').lower()
    text = re.sub(r'[`!@#$%^&*()_+\-=\[\]{};\':"\\|,.<>\/?~©«»—]', r'', text)
    text = ''.join([i for i in text if not i.isdigit()])

    lines = (line.strip() for line in text.splitlines())
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    text = '\n'.join(chunk for chunk in chunks if chunk)

    text = list(np.concatenate([sent_tokenize(i.strip()) for i in text.split('\n')]).flat)

    text_lemmatized = []
    for line in [t.split() for t in text]:
        line_lemmatized = ' '.join([morph.normal_forms(l)[0] for l in line if l not in stopwords_ru])
        text_lemmatized.append(line_lemmatized)

    data = pd.DataFrame(text_lemmatized, columns=['text']).drop_duplicates()
    data['company'] = company['Название']
    data['rating'] = company['№']
    data['url'] = pdf
    data = data[['rating', 'company', 'url', 'text']]

    return data

# %%
def parsing_site(company, url, depth, max_depth=0):
#     print(url)
    response = requests.get(url=url, timeout=timeout, headers=headers, verify=False)
    soup = BeautifulSoup(response.content, 'lxml')

    for script in soup(["script", "style"]):
        script.extract()

    text = soup.get_text()

    lines = (line.strip() for line in text.splitlines())
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    text = '\n'.join(chunk for chunk in chunks if chunk).replace('-\n', '').lower()
    text = re.sub(r'[`!@#$%^&*()_+\-=\[\]{};\':"\\|,.<>\/?~©«»—]', r'', text)
    text = ''.join([i for i in text if not i.isdigit()])

    text = list(np.concatenate([sent_tokenize(i.strip()) for i in text.split('\n')]).flat)

    text_lemmatized = []
    for line in [t.split() for t in text]:
        line_lemmatized = ' '.join([morph.normal_forms(l)[0] for l in line if l not in stopwords_ru])
        text_lemmatized.append(line_lemmatized)

    spans = list(filter(None, [span.string for span in soup.find_all('span')]))

    if len(spans):
        spans = '\n'.join(span for span in spans if span).replace('-\n', '').lower()
        spans = re.sub(r'[`!@#$%^&*()_+\-=\[\]{};\':"\\|,.<>\/?~©«»—]', r'', spans)
        spans = ''.join([i for i in spans if not i.isdigit()])

        spans = list(np.concatenate([sent_tokenize(i.strip()) for i in spans.split('\n')]).flat)
    else:
        spans = []

    spans_lemmatized = []
    for line in [s.split() for s in spans]:
        line_lemmatized = ' '.join([morph.normal_forms(l)[0] for l in line if l not in stopwords_ru])
        spans_lemmatized.append(line_lemmatized)

    df1 = pd.DataFrame(text_lemmatized, columns=['text'])
    df2 = pd.DataFrame(spans_lemmatized, columns=['text'])
    data = pd.concat([df1, df2]).drop_duplicates().reset_index(drop=True)
    data['company'] = company['Название']
    data['rating'] = company['№']
    data['url'] = url
    data = data[['rating', 'company', 'url', 'text']]

#     print(depth)
    if depth < max_depth:
        internalLinks = [
            a.get('href') for a in soup.find_all('a')
            if a.get('href') and a.get('href').startswith('/')
        ]
        internalLinks = [link[1:] for link in internalLinks]
        internalLinks = [*set(internalLinks)]
        internalLinks = list(filter(None, internalLinks))

        for link in internalLinks:
            if ".pdf" not in link and ".PDF" not in link:
                new_url = os.path.join(url[:url.rfind('www')], urlparse(url).netloc, link)
                try:
                    df = parsing_site(company, new_url, depth + 1, max_depth)
                    data = pd.concat([data, df]).drop_duplicates()
                except Exception as err:
                    print('ERROR', new_url, err)
                    continue

    return data

# %%
# %%time
max_depth = 1
parsed_data = pd.DataFrame()

# for i, company in raex_list[140:141].iterrows():
# for i, company in raex_list[7:8].iterrows():
for i, company in raex_list.iterrows():
    rating = company['№']
    name = company['Название']
    url = company['url_sustainability']
    
    try:
        if ".pdf" in url:
            df = parsing_pdf(company, url)
        else:
            df = parsing_site(company, url, 0, max_depth)
        parsed_data = pd.concat([parsed_data, df])
        print('DONE', i, name)
    except Exception as err:
        print('ERROR', i, name, err)
        continue

parsed_data = parsed_data.drop_duplicates()
parsed_data = parsed_data.reset_index(drop=True)
parsed_data.to_csv('parsed_data.csv', encoding='utf-8')
# Out:
# DONE 0 НЛМК
# DONE 1 «Полюс»
# ERROR /pda.uralkali.com/ru/ Invalid URL '/pda.uralkali.com/ru/': No scheme supplied. Perhaps you meant https:///pda.uralkali.com/ru/?
# DONE 2 «Уралкалий»
# DONE 3 «ЭЛ5-Энерго»
# DONE 4 «Полиметалл»
# ERROR /www.phosagro.com/pt/ Invalid URL '/www.phosagro.com/pt/': No scheme supplied. Perhaps you meant https:///www.phosagro.com/pt/?
# ERROR /www.phosagro.fr/ Invalid URL '/www.phosagro.fr/': No scheme supplied. Perhaps you meant https:///www.phosagro.fr/?
# ERROR /www.phosagro.es/ Invalid URL '/www.phosagro.es/': No scheme supplied. Perhaps you meant https:///www.phosagro.es/?
# ERROR /www.phosagro.com/it/ Invalid URL '/www.phosagro.com/it/': No scheme supplied. Perhaps you meant https:///www.phosagro.com/it/?
# ERROR /www.phosagro.de/ Invalid URL '/www.phosagro.de/': No scheme supplied. Perhaps you meant https:///www.phosagro.de/?
# ERROR /www.phosagro.com/sustainability/ Invalid URL '/www.phosagro.com/sustainability/': No scheme supplied. Perhaps you meant https:///www.phosagro.com/sustainability/?
# DONE 5 «ФосАгро», группа
# DONE 6 «МОСКОВСКИЙ КРЕДИТНЫЙ БАНК»
# DONE 7 «Норильский никель», горно-металлургическая компания
# DONE 8 «Северсталь»
# DONE 9 «ЛУКОЙЛ»
# DONE 10 ПАО "МТС"
# DONE 11 АФК «Система»
# DONE 12 «Татнефть», группа
# DONE 13 «Яндекс»
# DONE 14 Московская Биржа
# DONE 15 ПАО «Юнипро»
# DONE 16 «Русал», объединенная компания
# DONE 17 НОВАТЭК
# ERROR /limited.rosneft.ru Invalid URL '/limited.rosneft.ru': No scheme supplied. Perhaps you meant https:///limited.rosneft.ru?
# DONE 18 «Роснефть», нефтяная компания
# DONE 19 ЕВРАЗ
# DONE 20 СУЭК
# DONE 21 «Уралхим», ОХК
# DONE 22 «Сахалин Энерджи»
# DONE 23 «РусГидро»
# DONE 24 Магнитогорский металлургический комбинат (ММК)
# DONE 25 «Интер РАО»
# DONE 26 Акционерная компания «АЛРОСА»
# ERROR /www.gazprom.de/sustainability/ Invalid URL '/www.gazprom.de/sustainability/': No scheme supplied. Perhaps you meant https:///www.gazprom.de/sustainability/?
# DONE 101 «Башкирская содовая компания»
# DONE 102 «Сибантрацит», группа
# DONE 103 «Ашинский металлургический завод», группа
# DONE 104 «Квадра»
# DONE 105 ЧФМК
# DONE 106 Пигмент (КРАТА)
# DONE 107 «РуссНефть», нефтегазовая компания
# DONE 108 «Мечел»
# DONE 109 Казаньоргсинтез
# DONE 110 Новикомбанк
# DONE 111 «Ямал СПГ»
# DONE 112 «Русвинил»
# DONE 113 «Русская медная компания»
# DONE 114 «Т Плюс»
# DONE 115 «Титан», группа компаний (нефтехимия)
# DONE 116 «Азбука Вкуса» (сеть супермаркетов)
# DONE 117 ТГК-2
# DONE 118 «Славнефть», группа
# DONE 119 «Русский уголь»
# DONE 120 «Стройсервис»
# DONE 121 Сусуманзолото
# DONE 122 «УГМК»
# ERROR /zakupki.gazprom-neft.ru/ Invalid URL '/zakupki.gazprom-neft.ru/': No scheme supplied. Perhaps you meant https:///zakupki.gazprom-neft.ru/?
# ERROR /www.gpnbonus.ru/ Invalid URL '/www.gpnbonus.ru/': No scheme supplied. Perhaps you meant https:///www.gpnbonus.ru/?
# ERROR /www.gpnbonus.ru/login/ Invalid URL '/www.gpnbonus.ru/login/': No scheme supplied. Perhaps you meant https:///www.gpnbonus.ru/login/?
# ERROR /opti-24.com/ Invalid URL '/opti-24.com/': No scheme supplied. Perhaps you meant https:///opti-24.com/?
# DONE 123 «Газпром нефть»
# ERROR 124 «Вкусвилл» HTTPSConnectionPool(host='vkusvill.ru', port=443): Read timed out. (read timeout=25)
# DONE 125 «КамАЗ»
# ERROR /top.mail.ru/jump?from=1551685 Invalid URL '/top.mail.ru/jump?from=1551685': No scheme supplied. Perhaps you meant https:///top.mail.ru/jump?from=1551685?
# ERROR /en.taifnk.ru Invalid URL '/en.taifnk.ru': No scheme supplied. Perhaps you meant https:///en.taifnk.ru?
# DONE 126 ТАИФ-НК
# DONE 127 Золоторудная Компания ПАВЛИК
# DONE 128 Южуралзолото Группа Компаний
# DONE 129 Омск Карбон Групп
# DONE 130 «Фирма «Август»
# DONE 131 СДС Азот
# DONE 132 «Группа ПОЛИПЛАСТИК»
# DONE 133 "Нефтиса", нефтяная компания
# DONE 134 Карелия Палп
# DONE 135 «Щёкиноазот»
# DONE 136 Кордиант
# DONE 137 «Промышленно-металлургический холдинг» (ПМХ)
# DONE 138 "Титан", группа компаний (деревообработка)
# DONE 139 «Минудобрения»
# DONE 140 «Петропавловск», группа компаний
# CPU times: user 25min 33s, sys: 15.9 s, total: 25min 49s
# Wall time: 1h 3min 57s

# %%
parsed_data
# Out:
#          rating                           company  \
# 0             1                              НЛМК
# 1             1                              НЛМК
# 2             1                              НЛМК
# 3             1                              НЛМК
# 4             1                              НЛМК
# ...         ...                               ...
# 760446  158-160  «Петропавловск», группа компаний
# 760447  158-160  «Петропавловск», группа компаний
# 760448  158-160  «Петропавловск», группа компаний
# 760449  158-160  «Петропавловск», группа компаний
# 760450  158-160  «Петропавловск», группа компаний
#
#                                         url  \
# 0       https://nlmk.com/ru/sustainability/
# 1       https://nlmk.com/ru/sustainability/
# 2       https://nlmk.com/ru/sustainability/
# 3       https://nlmk.com/ru/sustainability/
# 4       https://nlmk.com/ru/sustainability/
# ...                                     ...
# 760446            POG-SR2020_RUS_080921.pdf
# 760447            POG-SR2020_RUS_080921.pdf
# 760448            POG-SR2020_RUS_080921.pdf
# 760449            POG-SR2020_RUS_080921.pdf
# 760450            POG-SR2020_RUS_080921.pdf
#
#                                                  text
# 0       устойчивый развитие подход политика приоритет
# 1            просмотр содержимое разрешить работа кук
# 2                                          pinsymbols
# 3                                        pinhamburger
# 4                                                pinq
# ...                                               ...
# 760446                          рубцов переулок далее
# 760447                      teamirpetropavlovskplccom
# 760448                     contactpetropavlovskplccom
# 760449       wwwpetropavlovskplccomпубличный компания
# 760450                                   ограниченный
#
# [760451 rows x 4 columns]

# %%
parsed_data.to_csv('parsed_data.csv', encoding='utf-8')

# %% [markdown]
# ### Тесты и проверки

# %%
company = raex_list.loc[7]
# company = raex_list.loc[140]
# company = raex_list.loc[12]
# company = raex_list.loc[18]
# company = raex_list.loc[31]
# company = raex_list.loc[2]
company = raex_list.loc[27]
name = company['Название']
url = company['url_sustainability']
company
# Out:
# №                                                                         28
# Название                                                           «Газпром»
# Код MOEX                                                                GAZP
# Подотрасль                             Интегрированные нефтегазовые компании
# ESG-рейтинг                                                              BBB
# E Rank                                                                    15
# E-рейтинг                                                                BBB
# S Rank                                                                    42
# S-рейтинг                                                                 BB
# G Rank                                                                    72
# G-рейтинг                                                                BBB
# Год последней оцененной отчетности                                      2021
# url                                                   https://www.gazprom.ru
# url_sustainability                    https://www.gazprom.ru/sustainability/
# Name: 27, dtype: object

# %%
response = requests.get(url=url, timeout=timeout, headers=headers, verify=False)
soup = BeautifulSoup(response.content, 'lxml')

for script in soup(["script", "style"]):
    script.extract()

internalLinks = [
    a.get('href') for a in soup.find_all('a')
    if a.get('href') and a.get('href').startswith('/')
]
internalLinks = [link[1:] for link in internalLinks]
internalLinks = [*set(internalLinks)]
internalLinks = list(filter(None, internalLinks))

print(url)

internalLinks
# Out:
# https://www.gazprom.ru/sustainability/
# ['sustainability/people/konkurs/',
#  'sustainability/environmental-protection/environmental-reports/',
#  'investors/',
#  'about/ms/quality-management-system/',
#  'tenders/',
#  'about/legal/policy-personal-data/cookie-notice/',
#  'sustainability/environmental-protection/energy-conservation/',
#  'about/production/gas-infrastructure-expansion/',
#  'sustainability/environmental-protection/hydrogen/',
#  'about/legal/policy-personal-data/cookie-notice/#cookies-settings',
#  'sustainability/sustainability-management/',
#  'about/strategy/innovation/one-window/',
#  'about/production/safety/',
#  'bulletin-board/',
#  '/www.gazprom.de/sustainability/',
#  'sustainability/sustainability-management/reports/',
#  'sustainability/ratings/openness-rating/',
#  'contacts/warning/',
#  'sustainability/people/about-people/',
#  'sustainability/local-communities/supporting-sports/',
#  'sustainability/local-communities/supporting-cultural-projects/',
#  'sustainability/environmental-protection/',
#  'sustainability/people/statistics/',
#  'sustainability/people/union/',
#  'about/strategy/innovation/',
#  'press/news/tag/environment/',
#  'about/legal/policy-personal-data/',
#  'sustainability/ratings/esg-indexes/',
#  'projects/',
#  'sustainability/local-communities/volunteering/',
#  'sustainability/local-communities/vulnerable-group/',
#  'about/strategy/innovation/research/',
#  'sustainability/sustainability-management/regulatory-documents/',
#  'sustainability/local-communities/indigenous-minorities/',
#  'sustainability/people/education/',
#  'sustainability/environmental-protection/environmental-impact/',
#  'sustainability/local-communities/children/',
#  'sustainability/ratings/carbon-disclosure-project/',
#  'accessibility/',
#  'press/',
#  '/www.gazprom.com/sustainability/',
#  'map/',
#  'sustainability/environmental-protection/ems/',
#  'sustainability/people/hr-policy/',
#  'sustainability/people/professional-standards/',
#  'sustainability/environmental-protection/vernadsky-fund/',
#  'sustainability/people/veterans/',
#  'sustainability/human-rights/',
#  'sustainability/sustainability-management/sustainability-policy/',
#  'about/',
#  'contacts/',
#  'about/strategy/innovation/tech-regulation/',
#  'sustainability/people/',
#  'about/strategy/innovation/intellectual-property/',
#  'sustainability/local-communities/',
#  'investors/corporate-governance/control-system/',
#  'sustainability/local-communities/regions-collaboration/',
#  'about/strategy/innovation/year-of-science/',
#  'sustainability/sustainability-management/sustainabity-management-system/',
#  'about/strategy/innovation/award/',
#  'sustainability/environmental-protection/energy-ms/',
#  'sustainability/ratings/']

# %%
for link in internalLinks:
    if ".pdf" not in link:
        new_url = os.path.join(url[:url.rfind('www')], urlparse(url).netloc, link)
        print(new_url)
# Out:
# https://www.gazprom.ru/sustainability/people/konkurs/
# https://www.gazprom.ru/sustainability/environmental-protection/environmental-reports/
# https://www.gazprom.ru/investors/
# https://www.gazprom.ru/about/ms/quality-management-system/
# https://www.gazprom.ru/tenders/
# https://www.gazprom.ru/about/legal/policy-personal-data/cookie-notice/
# https://www.gazprom.ru/sustainability/environmental-protection/energy-conservation/
# https://www.gazprom.ru/about/production/gas-infrastructure-expansion/
# https://www.gazprom.ru/sustainability/environmental-protection/hydrogen/
# https://www.gazprom.ru/about/legal/policy-personal-data/cookie-notice/#cookies-settings
# https://www.gazprom.ru/sustainability/sustainability-management/
# https://www.gazprom.ru/about/strategy/innovation/one-window/
# https://www.gazprom.ru/about/production/safety/
# https://www.gazprom.ru/bulletin-board/
# /www.gazprom.de/sustainability/
# https://www.gazprom.ru/sustainability/sustainability-management/reports/
# https://www.gazprom.ru/sustainability/ratings/openness-rating/
# https://www.gazprom.ru/contacts/warning/
# https://www.gazprom.ru/sustainability/people/about-people/
# https://www.gazprom.ru/sustainability/local-communities/supporting-sports/
# https://www.gazprom.ru/sustainability/local-communities/supporting-cultural-projects/
# https://www.gazprom.ru/sustainability/environmental-protection/
# https://www.gazprom.ru/sustainability/people/statistics/
# https://www.gazprom.ru/sustainability/people/union/
# https://www.gazprom.ru/about/strategy/innovation/
# https://www.gazprom.ru/press/news/tag/environment/
# https://www.gazprom.ru/about/legal/policy-personal-data/
# https://www.gazprom.ru/sustainability/ratings/esg-indexes/
# https://www.gazprom.ru/projects/
# https://www.gazprom.ru/sustainability/local-communities/volunteering/
# https://www.gazprom.ru/sustainability/local-communities/vulnerable-group/
# https://www.gazprom.ru/about/strategy/innovation/research/
# https://www.gazprom.ru/sustainability/sustainability-management/regulatory-documents/
# https://www.gazprom.ru/sustainability/local-communities/indigenous-minorities/
# https://www.gazprom.ru/sustainability/people/education/
# https://www.gazprom.ru/sustainability/environmental-protection/environmental-impact/
# https://www.gazprom.ru/sustainability/local-communities/children/
# https://www.gazprom.ru/sustainability/ratings/carbon-disclosure-project/
# https://www.gazprom.ru/accessibility/
# https://www.gazprom.ru/press/
# /www.gazprom.com/sustainability/
# https://www.gazprom.ru/map/
# https://www.gazprom.ru/sustainability/environmental-protection/ems/
# https://www.gazprom.ru/sustainability/people/hr-policy/
# https://www.gazprom.ru/sustainability/people/professional-standards/
# https://www.gazprom.ru/sustainability/environmental-protection/vernadsky-fund/
# https://www.gazprom.ru/sustainability/people/veterans/
# https://www.gazprom.ru/sustainability/human-rights/
# https://www.gazprom.ru/sustainability/sustainability-management/sustainability-policy/
# https://www.gazprom.ru/about/
# https://www.gazprom.ru/contacts/
# https://www.gazprom.ru/about/strategy/innovation/tech-regulation/
# https://www.gazprom.ru/sustainability/people/
# https://www.gazprom.ru/about/strategy/innovation/intellectual-property/
# https://www.gazprom.ru/sustainability/local-communities/
# https://www.gazprom.ru/investors/corporate-governance/control-system/
# https://www.gazprom.ru/sustainability/local-communities/regions-collaboration/
# https://www.gazprom.ru/about/strategy/innovation/year-of-science/
# https://www.gazprom.ru/sustainability/sustainability-management/sustainabity-management-system/
# https://www.gazprom.ru/about/strategy/innovation/award/
# https://www.gazprom.ru/sustainability/environmental-protection/energy-ms/
# https://www.gazprom.ru/sustainability/ratings/

# %%
max_depth = 1
parsing_site(company, url, 0, max_depth)
# Out:
#     rating                                            company  \
# 0        8  «Норильский никель», горно-металлургическая ко...
# 1        8  «Норильский никель», горно-металлургическая ко...
# 2        8  «Норильский никель», горно-металлургическая ко...
# 3        8  «Норильский никель», горно-металлургическая ко...
# 4        8  «Норильский никель», горно-металлургическая ко...
# ..     ...                                                ...
# 26       8  «Норильский никель», горно-металлургическая ко...
# 27       8  «Норильский никель», горно-металлургическая ко...
# 28       8  «Норильский никель», горно-металлургическая ко...
# 29       8  «Норильский никель», горно-металлургическая ко...
# 30       8  «Норильский никель», горно-металлургическая ко...
#
#                                          url  \
# 0   https://www.nornickel.ru/sustainability/
# 1   https://www.nornickel.ru/sustainability/
# 2   https://www.nornickel.ru/sustainability/
# 3   https://www.nornickel.ru/sustainability/
# 4   https://www.nornickel.ru/sustainability/
# ..                                       ...
# 26     https://www.nornickel.ru/other-sites/
# 27     https://www.nornickel.ru/other-sites/
# 28     https://www.nornickel.ru/other-sites/
# 29     https://www.nornickel.ru/other-sites/
# 30     https://www.nornickel.ru/other-sites/
#
#                                                  text
# 0                       устойчивый развитие норникель
# 1                                             карьера
# 2                                           поставщик
# 3                                    реализация актив
# 4                                         сайт группа
# ..                                                ...
# 26  норникель лидер горнометаллургический промышле...
# 27                          пао гмк норильский никель
# 28                               раскрытие информация
# 29                         страница ооо интерфаксцрка
# 30                 страница пао гмк норильский никель
#
# [2490 rows x 4 columns]

# %%
parsing_pdf(company, url)
